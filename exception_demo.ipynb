# %%
#syntax error
def demo1():
    a = 1
    b = 2
    c = a + 
    return c
# Out:
#   File "<ipython-input-6-5a4f0df44b3c>", line 4
#     c = a +
#             ^
# SyntaxError: invalid syntax

# %%
demo1()
# Out:
# 3

# %%
def demo2():
    symbol_exchange_map = {
        "IF2010": "CFFEX",
        "rb2101": "SHFE",
        "M2101": "DCE",
        "SR101": "CZCE",
    }
    exchange = symbol_exchange_map["IC2101"]
    return exchange

# %%
#key error
demo2()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-2897e35bc3ec> in <module>
# ----> 1 demo2()
#
# <ipython-input-4-6b57de17e608> in demo2()
#       6         "SR101": "CZCE",
#       7     }
# ----> 8     exchange = symbol_exchange_map["IC2101"]
#       9     return exchange
#
# KeyError: 'IC2101'

# %%
i = 0

# %%
def demo3():
    global i
    i += 1
    print(f"調用Demo3函數, 第{i}次")
    demo3()

# %%
#遞規深度出錯
demo3()
# Out:
# 調用Demo3函數, 第1次
# 調用Demo3函數, 第2次
# 調用Demo3函數, 第3次
# 調用Demo3函數, 第4次
# 調用Demo3函數, 第5次
# 調用Demo3函數, 第6次
# 調用Demo3函數, 第7次
# 調用Demo3函數, 第8次
# 調用Demo3函數, 第9次
# 調用Demo3函數, 第10次
# 調用Demo3函數, 第11次
# 調用Demo3函數, 第12次
# 調用Demo3函數, 第13次
# 調用Demo3函數, 第14次
# 調用Demo3函數, 第15次
# 調用Demo3函數, 第16次
# 調用Demo3函數, 第17次
# 調用Demo3函數, 第18次
# 調用Demo3函數, 第19次
# 調用Demo3函數, 第20次
# 調用Demo3函數, 第21次
# 調用Demo3函數, 第22次
# 調用Demo3函數, 第23次
# 調用Demo3函數, 第24次
# 調用Demo3函數, 第25次
# 調用Demo3函數, 第26次
# 調用Demo3函數, 第27次
# 調用Demo3函數, 第28次
# 調用Demo3函數, 第29次
# 調用Demo3函數, 第30次
# 調用Demo3函數, 第31次
# 調用Demo3函數, 第32次
# 調用Demo3函數, 第33次
# 調用Demo3函數, 第34次
# 調用Demo3函數, 第35次
# 調用Demo3函數, 第36次
# 調用Demo3函數, 第37次
# 調用Demo3函數, 第38次
# 調用Demo3函數, 第39次
# 調用Demo3函數, 第40次
# 調用Demo3函數, 第41次
# 調用Demo3函數, 第42次
# 調用Demo3函數, 第43次
# 調用Demo3函數, 第44次
# 調用Demo3函數, 第45次
# 調用Demo3函數, 第46次
# 調用Demo3函數, 第47次
# 調用Demo3函數, 第48次
# 調用Demo3函數, 第49次
# 調用Demo3函數, 第50次
# 調用Demo3函數, 第51次
# 調用Demo3函數, 第52次
# 調用Demo3函數, 第53次
# 調用Demo3函數, 第54次
# 調用Demo3函數, 第55次
# 調用Demo3函數, 第56次
# ...
