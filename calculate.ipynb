# %%
#變量賦值
a = 1
b = 2

# %%
#四則運算
print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# 3
# -1
# 2
# 0.5

# %%
#特殊除法
c = 10
d = 3
print(c/d)
print(c // d) #整除
print(c % d) #求餘
# Out:
# 3.3333333333333335

# %%
#求冪運算
print(c**2)#乘方
print(c**0)
print(100**(1/2))\#開方#變成浮點數
# Out:
# 100
# 1
# 10.0

# %%
#自增運算
count = 0

# %%
count += 1
print(count)
# Out:
# 5

# %%
count=count+1
print(count)
# Out:
# 8

# %%
count -= 2
print(count)
# Out:
# -18

# %%
count *= 2
print(count)
# Out:
# -144

# %%
#邏輯運算
print(3>2)
print(3<2)
print(3>=2)
print(3<=2)
print(3==2)
print(3!=2)
# Out:
# True
# False
# True
# False
# False
# True

# %%
#計算優先級
1+2*3
# Out:
# 7

# %%
(1+2)*3
# Out:
# 9

# %%
3*2**4
# Out:
# 48

# %%
4+5>8
# Out:
# True

# %%
4+(5>8)
# Out:
# 4

# %%
4+(5<8)#布爾值到整數的隱式轉換 False=0 True=1
# Out:
# 5

# %%
int(5>8)
# Out:
# 0
